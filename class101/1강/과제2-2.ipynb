# %% [markdown]
# # 과제 2
#     데이터 : "7.세종시_아파트(전월세)_실거래가.csv"
#     1) 세종시 데이터에서 컬럼 확인 후, unnamed 컬럼 제거
#     2) 전월세구분 컬럼에서 unique값 확인
#     3) index= 100~200, column = 전월세구분, 전용면적(㎡),보증금(만원)으로 이루어진 데이터프레임 추출
#     4) 0~200 index를 가진 행 삭제
#     5) 건축년도 컬럼 중복 제거 결과 출력

# %%
import pandas as pd
import numpy as np

# %%
filepath = "/content/drive/MyDrive/ADP24/class101/2.데이터_핸들링/2. 데이터 핸들링/2.2.행,열 선택,추가,삭제/7.세종시_아파트(전월세)_실거래가.csv"
df_sejong = pd.read_csv(filepath)
df_sejong.head()
# Out:
#    Unnamed: 0    계약년월  계약일          시군구  ... 보증금(만원)  월세(만원)   층  건축년도
# 0           0  201701   13  세종특별자치시 고운동  ...   10000       0  13  2015
# 1           1  201701   14  세종특별자치시 고운동  ...   18000       0  19  2015
# 2           2  201701   14  세종특별자치시 고운동  ...   17000       0  10  2015
# 3           3  201701   15  세종특별자치시 고운동  ...   17000       0   2  2015
# 4           4  201702    4  세종특별자치시 고운동  ...   10000      30  13  2015
#
# [5 rows x 13 columns]

# %%
# 1) 세종시 데이터에서 컬럼 확인 후, unnamed 컬럼 제거

# %%
df_sejong.columns
# Out:
# Index(['Unnamed: 0', '계약년월', '계약일', '시군구', '본번', '부번', '단지명', '전월세구분',
#        '전용면적(㎡)', '보증금(만원)', '월세(만원)', '층', '건축년도'],
#       dtype='object')

# %%
df_sejong.iloc[0::,1::]
# Out:
#          계약년월  계약일          시군구    본번  부번  ...   전용면적(㎡) 보증금(만원)  월세(만원)   층  건축년도
# 0      201701   13  세종특별자치시 고운동  1396   0  ...   84.9895   10000       0  13  2015
# 1      201701   14  세종특별자치시 고운동  1396   0  ...   84.9895   18000       0  19  2015
# 2      201701   14  세종특별자치시 고운동  1396   0  ...   59.8338   17000       0  10  2015
# 3      201701   15  세종특별자치시 고운동  1396   0  ...   84.9895   17000       0   2  2015
# 4      201702    4  세종특별자치시 고운동  1396   0  ...   84.9895   10000      30  13  2015
# ...       ...  ...          ...   ...  ..  ...       ...     ...     ...  ..   ...
# 38890  202011   21  세종특별자치시 해밀동  6402   1  ...  102.8300   10000     100   5  2020
# 38891  202012    8  세종특별자치시 해밀동  6402   1  ...  102.5300   10000      95  14  2020
# 38892  202012   11  세종특별자치시 해밀동  6402   1  ...   84.9500   30000       0  18  2020
# 38893  202012   12  세종특별자치시 해밀동  6402   1  ...   84.9500   34000       0  18  2020
# ...

# %%
df_sejong.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df_sejong
# Out:
#          계약년월  계약일          시군구    본번  부번  ...   전용면적(㎡) 보증금(만원)  월세(만원)   층  건축년도
# 0      201701   13  세종특별자치시 고운동  1396   0  ...   84.9895   10000       0  13  2015
# 1      201701   14  세종특별자치시 고운동  1396   0  ...   84.9895   18000       0  19  2015
# 2      201701   14  세종특별자치시 고운동  1396   0  ...   59.8338   17000       0  10  2015
# 3      201701   15  세종특별자치시 고운동  1396   0  ...   84.9895   17000       0   2  2015
# 4      201702    4  세종특별자치시 고운동  1396   0  ...   84.9895   10000      30  13  2015
# ...       ...  ...          ...   ...  ..  ...       ...     ...     ...  ..   ...
# 38890  202011   21  세종특별자치시 해밀동  6402   1  ...  102.8300   10000     100   5  2020
# 38891  202012    8  세종특별자치시 해밀동  6402   1  ...  102.5300   10000      95  14  2020
# 38892  202012   11  세종특별자치시 해밀동  6402   1  ...   84.9500   30000       0  18  2020
# 38893  202012   12  세종특별자치시 해밀동  6402   1  ...   84.9500   34000       0  18  2020
# ...

# %%
# 2) 전월세구분 컬럼에서 unique값 확인

# %%
df_sejong['전월세구분'].unique()
# Out:
# array(['전세', '월세'], dtype=object)

# %%
# 3) index= 100~200, column = 전월세구분, 전용면적(㎡),보증금(만원)으로 이루어진 데이터프레임 추출

# %%
df_extracted = df_sejong.loc[100:200,['전월세구분','전용면적(㎡)','보증금(만원)']]
df_extracted
# Out:
#     전월세구분  전용면적(㎡)  보증금(만원)
# 100    전세  73.7130    13000
# 101    월세  73.7130     1200
# 102    전세  84.9837    15000
# 103    전세  73.7130    11000
# 104    전세  73.7130    10000
# ..    ...      ...      ...
# 196    전세  59.9917     8000
# 197    전세  59.9917    11000
# 198    월세  84.9894     1000
# 199    전세  84.9894    15000
# 200    전세  59.9917    12000
#
# [101 rows x 3 columns]

# %%
# 4) 0~200 index를 가진 행 삭제

# %%
df_sejong.drop(range(0,201),inplace=True)
df_sejong
# Out:
#          계약년월  계약일          시군구    본번  부번  ...   전용면적(㎡) 보증금(만원)  월세(만원)   층  건축년도
# 201    201707   29  세종특별자치시 고운동  1393   0  ...   59.9917    1000      40   3  2015
# 202    201708    4  세종특별자치시 고운동  1393   0  ...   73.9816   12000       0  16  2015
# 203    201708   10  세종특별자치시 고운동  1393   0  ...   73.9816   13000       0   9  2015
# 204    201708   12  세종특별자치시 고운동  1393   0  ...   73.9816   13000       0   9  2015
# 205    201708   14  세종특별자치시 고운동  1393   0  ...   84.9894   15000       0  14  2015
# ...       ...  ...          ...   ...  ..  ...       ...     ...     ...  ..   ...
# 38890  202011   21  세종특별자치시 해밀동  6402   1  ...  102.8300   10000     100   5  2020
# 38891  202012    8  세종특별자치시 해밀동  6402   1  ...  102.5300   10000      95  14  2020
# 38892  202012   11  세종특별자치시 해밀동  6402   1  ...   84.9500   30000       0  18  2020
# 38893  202012   12  세종특별자치시 해밀동  6402   1  ...   84.9500   34000       0  18  2020
# ...

# %%
# 5) 건축년도 컬럼 중복 제거 결과 출력

# %%
df_sejong['건축년도'].drop_duplicates()
# Out:
# 201      2015
# 473      2014
# 1898     2000
# 1973     2007
# 1996     2016
# 1998     2013
# 2019     2017
# 2036     2018
# 2039     2019
# 2826     2012
# 4180     2002
# 4184     1992
# 4186     1994
# 6480     2001
# 6535     1997
# 6538     1991
# 6551     1989
# 6563     2003
# 6564     1996
# 6823     2006
# 6839     1999
# 6880     2008
# 6936     1998
# 8404     2011
# 15189    1980
# 19801    2020
# 33640    1988
# Name: 건축년도, dtype: int64
