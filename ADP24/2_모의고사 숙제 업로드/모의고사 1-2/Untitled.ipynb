# %% [markdown]
# # 모의고사 1-2 통계분석 Q1~5

# %%
#---------------------------------------------------------------------------------------
# Q1) FIFA데이터에서 각 선수의 키는 Heghit변수에 피트와 인치로 입력되어 있습니다. 
#      이를 cm로 변환하여 새로운 변수 Height_cm을 생성하시오. 
#      ( “ ' ” 앞의 숫자는 피트이며, “ ' ” 뒤의 숫자는 인치, 1피트 = 30cm, 1인치 = 2.5cm)
#---------------------------------------------------------------------------------------

# %%
# %pwd
# Out:
# '/home/jupyter/ADP/ADP24/2_모의고사 숙제 업로드/모의고사 1-2'

# %%
import pandas as pd
import numpy as np
df_fifa = pd.read_csv("FIFA.csv", encoding="cp949")
df_fifa
# Out:
#            ID                Name  Age Nationality  Overall  \
# 0      158023            L. Messi   31   Argentina       94
# 1       20801   Cristiano Ronaldo   33    Portugal       94
# 2      190871           Neymar Jr   26      Brazil       92
# 3      193080              De Gea   27       Spain       91
# 4      192985        K. De Bruyne   27     Belgium       91
# ...       ...                 ...  ...         ...      ...
# 16637  238813        J. Lundstram   19     England       47
# 16638  243165  N. Christoffersson   19      Sweden       47
# 16639  241638           B. Worman   16     England       47
# 16640  246268      D. Walker-Rice   17     England       47
# 16641  246269           G. Nugent   16     England       46
#
#                       Club Preferred_Foot       Work_Rate Position  \
# 0             FC Barcelona           Left  Medium/ Medium       RF
# 1                 Juventus          Right       High/ Low       ST
# 2      Paris Saint-Germain          Right    High/ Medium       LW
# 3        Manchester United          Right  Medium/ Medium       GK
# 4          Manchester City          Right      High/ High      RCM
# ...                    ...            ...             ...      ...
# 16637      Crewe Alexandra          Right  Medium/ Medium       CM
# 16638       Trelleborgs FF          Right  Medium/ Medium       ST
# 16639     Cambridge United          Right  Medium/ Medium       ST
# 16640      Tranmere Rovers          Right  Medium/ Medium       RW
# 16641      Tranmere Rovers          Right  Medium/ Medium       CM
#
#        Jersey_Number  Contract_Valid_Until Height  Weight_lb  Release_Clause  \
# 0                 10                  2021    5'7        159          226500
# 1                  7                  2022    6'2        183          127100
# 2                 10                  2022    5'9        150          228100
# 3                  1                  2020    6'4        168          138600
# 4                  7                  2023   5'11        154          196400
# ...              ...                   ...    ...        ...             ...
# 16637             22                  2019    5'9        134             143
# 16638             21                  2020    6'3        170             113
# 16639             33                  2021    5'8        148             165
# 16640             34                  2019   5'10        154             143
# 16641             33                  2019   5'10        176             165
#
#         Value  Wage
# 0      110500   565
# 1       77000   405
# 2      118500   290
# 3       72000   260
# 4      102000   355
# ...       ...   ...
# 16637      60     1
# 16638      60     1
# 16639      60     1
# 16640      60     1
# 16641      60     1
#
# [16642 rows x 16 columns]

# %%
df_fifa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16642 entries, 0 to 16641
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    16642 non-null  int64
#  1   Name                  16642 non-null  object
#  2   Age                   16642 non-null  int64
#  3   Nationality           16642 non-null  object
#  4   Overall               16642 non-null  int64
#  5   Club                  16642 non-null  object
#  6   Preferred_Foot        16642 non-null  object
#  7   Work_Rate             16642 non-null  object
#  8   Position              16642 non-null  object
#  9   Jersey_Number         16642 non-null  int64
#  10  Contract_Valid_Until  16642 non-null  int64
#  11  Height                16642 non-null  object
#  12  Weight_lb             16642 non-null  int64
#  13  Release_Clause        16642 non-null  int64
#  14  Value                 16642 non-null  int64
#  15  Wage                  16642 non-null  int64
# dtypes: int64(9), object(7)
# memory usage: 2.0+ MB

# %%
df_fifa["Height_cm"] = df_fifa["Height"]

# %%
df_fifa["Height_cm"].map(lambda x: df_fifa.Height_cm.str.split("'")[0])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_4979/2867398699.py in <module>
# ----> 1 df_fifa["Height_cm"].map(lambda x: df_fifa.Height_cm.str.split("'")[0])
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/series.py in map(self, arg, na_action)
#    4159         dtype: object
#    4160         """
# -> 4161         new_values = super()._map_values(arg, na_action=na_action)
#    4162         return self._constructor(new_values, index=self.index).__finalize__(
#    4163             self, method="map"
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/base.py in _map_values(self, mapper, na_action)
#     868
#     869         # mapper is a function
# --> 870         new_values = map_f(values, mapper)
#     871
#     872         return new_values
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# /tmp/ipykernel_4979/2867398699.py in <lambda>(x)
# ----> 1 df_fifa["Height_cm"].map(lambda x: df_fifa.Height_cm.str.split("'")[0])
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# --> 116             return func(self, *args, **kwargs)
#     117
#     118         wrapper.__name__ = func_name
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/strings/accessor.py in split(self, pat, n, expand)
#     787     @forbid_nonstring_types(["bytes"])
#     788     def split(self, pat=None, n=-1, expand=False):
# --> 789         result = self._data.array._str_split(pat, n, expand)
#     790         return self._wrap_result(result, returns_string=expand, expand=expand)
#     791
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/strings/object_array.py in _str_split(self, pat, n, expand)
#     320                 regex = re.compile(pat)
#     321                 f = lambda x: regex.split(x, maxsplit=n)
# --> 322         return self._str_map(f, dtype=object)
#     323
#     324     def _str_rsplit(self, pat=None, n=-1):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/strings/object_array.py in _str_map(self, f, na_value, dtype, convert)
#      67         map_convert = convert and not np.all(mask)
#      68         try:
# ---> 69             result = lib.map_infer_mask(arr, f, mask.view(np.uint8), map_convert)
#      70         except (TypeError, AttributeError) as e:
#      71             # Reraise the exception if callable `f` got wrong number of args.
#
# /opt/conda/lib/python3.7/site-packages/pandas/_libs/lib.pyx in pandas._libs.lib.map_infer_mask()
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/strings/object_array.py in <lambda>(x)
#     314                 if n is None or n == 0:
#     315                     n = -1
# --> 316                 f = lambda x: x.split(pat, n)
#     317             else:
#     318                 if n is None or n == -1:
#
# KeyboardInterrupt:
