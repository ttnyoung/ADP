# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#로지스틱-회귀분석-과제" data-toc-modified-id="로지스틱-회귀분석-과제-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>로지스틱 회귀분석 과제</a></span></li></ul></div>

# %% [markdown]
# # 로지스틱 회귀분석 과제
#
# - 1) 타이타닉 데이터를 불러오고 survived를 종속변수(y)로, 나머지 변수들은 독립변수(X)로 설정하세요

# %%
import pandas as pd 
df_t = pd.read_csv("./data/titanic.csv")
df_t
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#      adult_male  embark_town
# 0          True  Southampton
# 1         False    Cherbourg
# 2         False  Southampton
# 3         False  Southampton
# 4          True  Southampton
# ..          ...          ...
# 886        True  Southampton
# 887       False  Southampton
# 888       False  Southampton
# 889        True    Cherbourg
# 890        True   Queenstown
#
# [891 rows x 11 columns]

# %% [markdown]
# - 2) X의 결측치가 존재하는 행을 삭제하고, 범주형 변수를 더미변수화 시키세요

# %%
df_t_dropna = df_t.dropna()
y=df_t_dropna['survived']
X=df_t_dropna.drop(columns=['survived'],axis=1)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   pclass       712 non-null    int64
#  1   sex          712 non-null    object
#  2   age          712 non-null    float64
#  3   sibsp        712 non-null    int64
#  4   parch        712 non-null    int64
#  5   fare         712 non-null    float64
#  6   embarked     712 non-null    object
#  7   class        712 non-null    object
#  8   adult_male   712 non-null    bool
#  9   embark_town  712 non-null    object
# dtypes: bool(1), float64(2), int64(3), object(4)
# memory usage: 56.3+ KB

# %%
X
# Out:
#      pclass     sex   age  sibsp  parch     fare embarked   class  adult_male  \
# 0         3    male  22.0      1      0   7.2500        S   Third        True
# 1         1  female  38.0      1      0  71.2833        C   First       False
# 2         3  female  26.0      0      0   7.9250        S   Third       False
# 3         1  female  35.0      1      0  53.1000        S   First       False
# 4         3    male  35.0      0      0   8.0500        S   Third        True
# ..      ...     ...   ...    ...    ...      ...      ...     ...         ...
# 885       3  female  39.0      0      5  29.1250        Q   Third       False
# 886       2    male  27.0      0      0  13.0000        S  Second        True
# 887       1  female  19.0      0      0  30.0000        S   First       False
# 889       1    male  26.0      0      0  30.0000        C   First        True
# 890       3    male  32.0      0      0   7.7500        Q   Third        True
#
#      embark_town
# 0    Southampton
# 1      Cherbourg
# 2    Southampton
# 3    Southampton
# 4    Southampton
# ..           ...
# 885   Queenstown
# 886  Southampton
# 887  Southampton
# 889    Cherbourg
# 890   Queenstown
#
# [712 rows x 10 columns]

# %%
#파생변수인 pclass, embarked를 삭제한다.
X = X.drop(columns=['pclass','embarked'],axis = 1)

# %%
#범주형 변수는 sex, class, adult_male, embark_town
X = pd.get_dummies(X, columns = ['sex','class','adult_male','embark_town'])
X
# Out:
#       age  sibsp  parch     fare  sex_female  sex_male  class_First  \
# 0    22.0      1      0   7.2500           0         1            0
# 1    38.0      1      0  71.2833           1         0            1
# 2    26.0      0      0   7.9250           1         0            0
# 3    35.0      1      0  53.1000           1         0            1
# 4    35.0      0      0   8.0500           0         1            0
# ..    ...    ...    ...      ...         ...       ...          ...
# 885  39.0      0      5  29.1250           1         0            0
# 886  27.0      0      0  13.0000           0         1            0
# 887  19.0      0      0  30.0000           1         0            1
# 889  26.0      0      0  30.0000           0         1            1
# 890  32.0      0      0   7.7500           0         1            0
#
#      class_Second  class_Third  adult_male_False  adult_male_True  \
# 0               0            1                 0                1
# 1               0            0                 1                0
# 2               0            1                 1                0
# 3               0            0                 1                0
# 4               0            1                 0                1
# ..            ...          ...               ...              ...
# 885             0            1                 1                0
# 886             1            0                 0                1
# 887             0            0                 1                0
# 889             0            0                 0                1
# 890             0            1                 0                1
#
#      embark_town_Cherbourg  embark_town_Queenstown  embark_town_Southampton
# 0                        0                       0                        1
# 1                        1                       0                        0
# 2                        0                       0                        1
# 3                        0                       0                        1
# 4                        0                       0                        1
# ..                     ...                     ...                      ...
# 885                      0                       1                        0
# 886                      0                       0                        1
# 887                      0                       0                        1
# 889                      1                       0                        0
# 890                      0                       1                        0
#
# [712 rows x 14 columns]

# %% [markdown]
# - 3) 독립변수(X)를 StandardScaler를 통해 변환하세요

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X['fare']=scaler.fit_transform(X[['fare']])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   age                      712 non-null    float64
#  1   sibsp                    712 non-null    int64
#  2   parch                    712 non-null    int64
#  3   fare                     712 non-null    float64
#  4   sex_female               712 non-null    uint8
#  5   sex_male                 712 non-null    uint8
#  6   class_First              712 non-null    uint8
#  7   class_Second             712 non-null    uint8
#  8   class_Third              712 non-null    uint8
#  9   adult_male_False         712 non-null    uint8
#  10  adult_male_True          712 non-null    uint8
#  11  embark_town_Cherbourg    712 non-null    uint8
#  12  embark_town_Queenstown   712 non-null    uint8
#  13  embark_town_Southampton  712 non-null    uint8
# dtypes: float64(2), int64(2), uint8(10)
# memory usage: 34.8 KB

# %% [markdown]
# - 4) X와 y를 홀드아웃 기법을 사용하여 7:3으로 분할하세요

# %%
# 훈련셋 평가셋 분리하기
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, train_size=0.7,
                                                   test_size = 0.3, random_state=123)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (498, 14) (214, 14) (498,) (214,)

# %% [markdown]
# - 5) X_train과 y_train을 가지고 로지스틱 회귀분석모델을 만드세요

# %%
# 로지스틱회귀모형 모델링
import statsmodels.api as sm
model = sm.Logit(y_train, X_train)
result = model.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.419741
#          Iterations 6

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               survived   No. Observations:                  498
# Model:                          Logit   Df Residuals:                      487
# Method:                           MLE   Df Model:                           10
# Date:                Wed, 05 Jan 2022   Pseudo R-squ.:                  0.3777
# Time:                        20:42:04   Log-Likelihood:                -209.03
# converged:                       True   LL-Null:                       -335.88
# Covariance Type:            nonrobust   LLR p-value:                 9.091e-49
# ===========================================================================================
#                               coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# age                        -0.0276      0.011     -2.568      0.010      -0.049      -0.007
# sibsp                      -0.5892      0.166     -3.548      0.000      -0.915      -0.264
# parch                      -0.1286      0.163     -0.789      0.430      -0.448       0.191
# fare                        0.1766      0.168      1.050      0.294      -0.153       0.506
# sex_female                  0.5862   1.33e+07   4.41e-08      1.000    -2.6e+07     2.6e+07
# sex_male                    0.1667    1.3e+07   1.28e-08      1.000   -2.55e+07    2.55e+07
# class_First                 1.3750   1.22e+07   1.13e-07      1.000   -2.39e+07    2.39e+07
# class_Second                0.3122   1.21e+07   2.58e-08      1.000   -2.37e+07    2.37e+07
# class_Third                -0.9344   1.22e+07  -7.66e-08      1.000   -2.39e+07    2.39e+07
# adult_male_False            1.6661   1.62e+07   1.03e-07      1.000   -3.17e+07    3.17e+07
# adult_male_True            -0.9132   1.54e+07  -5.93e-08      1.000   -3.02e+07    3.02e+07
# embark_town_Cherbourg       0.4624        nan        nan        nan         nan         nan
# embark_town_Queenstown      0.1208        nan        nan        nan         nan         nan
# embark_town_Southampton     0.1697        nan        nan        nan         nan         nan
# ===========================================================================================
# """

# %% [markdown]
# - 6) 변수선택법을 통해 최적의 회귀 방정식을 구하고, 유의한 변수만을 추출하세요. (변수선택법은 복사 붙여넣기)

# %%
import time
import itertools
def processSubset(X,y, feature_set):
            model = sm.Logit(y,X[list(feature_set)]) # Modeling
            regr = model.fit() # 모델 학습
            AIC = regr.aic # 모델의 AIC
            return {"model":regr, "AIC":AIC}
        
'''
전진선택법
'''
def forward(X, y, predictors):
    
    # 데이터 변수들이 미리정의된 predictors에 있는지 없는지 확인 및 분류
    remaining_predictors = [p for p in X.columns if p not in predictors]
    results = []
    for p in remaining_predictors:
        results.append(processSubset(X=X, y= y, feature_set=predictors+[p]))
        
    # 데이터프레임으로 변환
    models = pd.DataFrame(results)

    # AIC가 가장 낮은 것을 선택
    best_model = models.loc[models['AIC'].argmin()] # index

    print("Processed ", models.shape[0], "models on", len(predictors)+1, "predictors in")
    print('Selected predictors:',best_model['model'].model.exog_names,' AIC:',best_model[0] )
    return best_model

'''
후진소거법
'''
def backward(X,y,predictors):
    tic = time.time()
    results = []
    
    # 데이터 변수들이 미리정의된 predictors 조합 확인
    for combo in itertools.combinations(predictors, len(predictors) - 1):
        results.append(processSubset(X=X, y= y,feature_set=list(combo)))
    models = pd.DataFrame(results)
    
    # 가장 낮은 AIC를 가진 모델을 선택
    best_model = models.loc[models['AIC'].argmin()]
    toc = time.time()
    print("Processed ", models.shape[0], "models on", len(predictors) - 1, "predictors in",
          (toc - tic))
    print('Selected predictors:',best_model['model'].model.exog_names,' AIC:',best_model[0] )
    return best_model



'''
단계적 선택법
'''

def Stepwise_model(X,y):
    Stepmodels = pd.DataFrame(columns=["AIC", "model"])
    tic = time.time()
    predictors = [X.columns[0]]
    Smodel_before = processSubset(X,y,predictors)['AIC']
    # 변수 1~10개 : 0~9 -> 1~10
    for i in range(1, len(X.columns) + 1):
        Forward_result = forward(X=X, y=y, predictors=predictors) # constant added
        print('forward')
        Stepmodels.loc[i] = Forward_result
        predictors = Stepmodels.loc[i]["model"].model.exog_names
        predictors = [ k for k in predictors]
        Backward_result = backward(X=X, y=y, predictors=predictors)
        if Backward_result['AIC']< Forward_result['AIC']:
            Stepmodels.loc[i] = Backward_result
            predictors = Stepmodels.loc[i]["model"].model.exog_names
            Smodel_before = Stepmodels.loc[i]["AIC"]
            predictors = [ k for k in predictors]
            print('backward')
        if Stepmodels.loc[i]['AIC']> Smodel_before:
            break
        else:
            Smodel_before = Stepmodels.loc[i]["AIC"]
    toc = time.time()
    print("Total elapsed time:", (toc - tic), "seconds.")
    return (Stepmodels['model'][len(Stepmodels['model'])])

# %%
best_model = Stepwise_model(X=X_train,y=y_train)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.670569
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.669116
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.666633
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.617857
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.538602
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.546877
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.606655
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.664750
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.613245
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.564982
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.521197
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.652321
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.669951
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.662210
#          Iterations 4
# Processed  13 models on 2 predictors in
# Selected predictors: ['age', 'adult_male_True']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e0450>
# forward
# Optimization terminated successfully.
#          Current function value: 0.670569
#          Iterations 4
# Optimization terminated successfully.
#          Current function value: 0.562476
#          Iterations 5
# Processed  2 models on 1 predictors in 0.005630970001220703
# Selected predictors: ['adult_male_True']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e0fd0>
# Optimization terminated successfully.
#          Current function value: 0.515692
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.520868
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.499175
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.508011
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.520546
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.477059
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516655
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.502047
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.514768
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.505772
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.519808
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.521154
#          Iterations 6
# Processed  12 models on 3 predictors in
# Selected predictors: ['age', 'adult_male_True', 'class_First']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e9b50>
# forward
# Optimization terminated successfully.
#          Current function value: 0.521197
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.606655
#          Iterations 5
# Optimization terminated successfully.
#          Current function value: 0.482667
#          Iterations 6
# Processed  3 models on 2 predictors in 0.01114797592163086
# Selected predictors: ['adult_male_True', 'class_First']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e9a50>
# Optimization terminated successfully.
#          Current function value: 0.470560
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476726
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476145
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.460727
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476367
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.474318
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.469206
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.472641
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.476798
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.475742
#          Iterations 6
# Processed  11 models on 4 predictors in
# Selected predictors: ['age', 'adult_male_True', 'class_First', 'class_Second']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e9ad0>
# forward
# Optimization terminated successfully.
#          Current function value: 0.477059
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.516655
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.569592
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449668
#          Iterations 6
# Processed  4 models on 3 predictors in 0.015397787094116211
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec44abdd90>
# backward
# Optimization terminated successfully.
#          Current function value: 0.449093
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.439449
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.448129
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449226
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.447369
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.447314
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449323
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449323
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446283
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449652
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449350
#          Iterations 6
# Processed  11 models on 4 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456c62d0>
# forward
# Optimization terminated successfully.
#          Current function value: 0.449668
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.479198
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.543595
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.666347
#          Iterations 5
# Processed  4 models on 3 predictors in 0.017884016036987305
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456ce750>
# Optimization terminated successfully.
#          Current function value: 0.439414
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.439222
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.438768
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.432844
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.439256
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431171
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431171
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.435618
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.439089
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.438528
#          Iterations 6
# Processed  10 models on 5 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e93d0>
# forward
# Optimization terminated successfully.
#          Current function value: 0.439449
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.449323
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.478910
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.540898
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.600657
#          Iterations 5
# Processed  5 models on 4 predictors in 0.022568941116333008
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e9d90>
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.430790
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431171
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431171
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431171
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.429443
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431163
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.429826
#          Iterations 6
# Processed  9 models on 6 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec449ef610>
# forward
# Optimization terminated successfully.
#          Current function value: 0.431171
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.439414
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.447131
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.470207
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.500144
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.564472
#          Iterations 6
# Processed  6 models on 5 predictors in 0.03185701370239258
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a0cb90>
# Optimization terminated successfully.
#          Current function value: 0.422960
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422103
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.423252
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422377
#          Iterations 6
# Processed  8 models on 7 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a0ce50>
# forward
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.431171
#          Iterations 8
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.447131
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Processed  7 models on 6 predictors in 0.035768985748291016
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456ce950>
# Optimization terminated successfully.
#          Current function value: 0.422960
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422103
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.423252
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422377
#          Iterations 6
# Processed  7 models on 8 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False', 'fare']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a0cfd0>
# forward
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446815
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Processed  8 models on 7 predictors in 0.028680086135864258
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e9790>
# backward
# Optimization terminated successfully.
#          Current function value: 0.422960
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422103
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.423252
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422377
#          Iterations 6
# Processed  7 models on 8 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False', 'fare']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a0cd50>
# forward
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446815
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Processed  8 models on 7 predictors in 0.028326988220214844
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec4534b850>
# backward
# Optimization terminated successfully.
#          Current function value: 0.422960
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422103
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.423252
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422377
#          Iterations 6
# Processed  7 models on 8 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False', 'fare']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a0c6d0>
# forward
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446815
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Processed  8 models on 7 predictors in 0.030183792114257812
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456e9d90>
# backward
# Optimization terminated successfully.
#          Current function value: 0.422960
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422103
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.423252
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422377
#          Iterations 6
# Processed  7 models on 8 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False', 'fare']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a0c150>
# forward
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446815
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Processed  8 models on 7 predictors in 0.02839183807373047
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec456ce950>
# backward
# Optimization terminated successfully.
#          Current function value: 0.422960
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422103
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.423252
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422377
#          Iterations 6
# Processed  7 models on 8 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False', 'fare']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a0c890>
# forward
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446815
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Processed  8 models on 7 predictors in 0.027843952178955078
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a23910>
# backward
# Optimization terminated successfully.
#          Current function value: 0.422960
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422103
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.423252
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422377
#          Iterations 6
# Processed  7 models on 8 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False', 'fare']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a23310>
# forward
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446815
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Processed  8 models on 7 predictors in 0.02889871597290039
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a0ced0>
# backward
# Optimization terminated successfully.
#          Current function value: 0.422960
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422550
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.422103
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.423252
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.422377
#          Iterations 6
# Processed  7 models on 8 predictors in
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False', 'fare']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a3b990>
# forward
# Optimization terminated successfully.
#          Current function value: 0.423261
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.428664
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.446815
#          Iterations 7
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Optimization terminated successfully.
#          Current function value: 0.421695
#          Iterations 6
# Processed  8 models on 7 predictors in 0.02935004234313965
# Selected predictors: ['adult_male_True', 'class_First', 'class_Second', 'sibsp', 'class_Third', 'age', 'adult_male_False']  AIC: <statsmodels.discrete.discrete_model.BinaryResultsWrapper object at 0x7fec45a3b710>
# backward
# Total elapsed time: 0.874640941619873 seconds.
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               survived   No. Observations:                  498
# Model:                          Logit   Df Residuals:                      492
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 05 Jan 2022   Pseudo R-squ.:                  0.3724
# Time:                        20:42:15   Log-Likelihood:                -210.78
# converged:                       True   LL-Null:                       -335.88
# Covariance Type:            nonrobust   LLR p-value:                 5.019e-52
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# adult_male_True     -0.7567        nan        nan        nan         nan         nan
# class_First          1.8093        nan        nan        nan         nan         nan
# class_Second         0.4631        nan        nan        nan         nan         nan
# sibsp               -0.6549      0.146     -4.478      0.000      -0.942      -0.368
# class_Third         -0.8385        nan        nan        nan         nan         nan
# age                 -0.0278      0.010     -2.734      0.006      -0.048      -0.008
# adult_male_False     2.1905        nan        nan        nan         nan         nan
# ====================================================================================
# """

# %%
best_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               survived   No. Observations:                  498
# Model:                          Logit   Df Residuals:                      492
# Method:                           MLE   Df Model:                            5
# Date:                Wed, 05 Jan 2022   Pseudo R-squ.:                  0.3724
# Time:                        20:42:25   Log-Likelihood:                -210.78
# converged:                       True   LL-Null:                       -335.88
# Covariance Type:            nonrobust   LLR p-value:                 5.019e-52
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# adult_male_True     -0.7567        nan        nan        nan         nan         nan
# class_First          1.8093        nan        nan        nan         nan         nan
# class_Second         0.4631        nan        nan        nan         nan         nan
# sibsp               -0.6549      0.146     -4.478      0.000      -0.942      -0.368
# class_Third         -0.8385        nan        nan        nan         nan         nan
# age                 -0.0278      0.010     -2.734      0.006      -0.048      -0.008
# adult_male_False     2.1905        nan        nan        nan         nan         nan
# ====================================================================================
# """

# %% [markdown]
# - 6) X_test값을 가지고 y_predict값을 구한 후 혼동행렬을 만드세요

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, recall_score, precision_score, f1_score
# 혼동행렬
y_predict = best_model.predict(X_test[best_model.params.index])
y_predict = round(y_predict)
cm = confusion_matrix(y_test,y_predict)
print(cm)
# Out:
# [[110  17]
#  [ 20  67]]

# %% [markdown]
# - 7) X_test값을 가지고 y_predict_proba 값을 구한 후 roc_auc_score를 구하고 해석하세요

# %%
y_predict_proba = best_model.predict(X_test[best_model.params.index])
from sklearn.metrics import roc_auc_score

roc_auc_score(y_test,y_predict_proba)
# Out:
# 0.8693999456964431

# %%
#roc_auc 면적이 약 0.869로 TPR(민감도)가 높고 FPR(1-특이도)가 낮으므로, 모델의 성능이 좋다고 할 수 있음

# %% [markdown]
# - 7) 회귀계수를 구하고, 유의한 회귀계수의 값을 설명하세요

# %%
import numpy as np
np.exp(best_model.params)
# Out:
# adult_male_True     0.469196
# class_First         6.106086
# class_Second        1.588940
# sibsp               0.519479
# class_Third         0.432338
# age                 0.972620
# adult_male_False    8.940036
# dtype: float64

# %%
# adult_male_True (0->1) 생존확률이 약 53% 줄어듬
# class_First 생존확률이 약 6배 올라감
# class_Second 생존확률이 약 1.6배 올라감
# class_Third 생존확률이 약 48% 줄어듬
# age 1살 많을수록 생존확률이 약 3% 줄어듬
# adult_male_False 성인여성이 아닐수록 생존확률이 약 9배 올라감
